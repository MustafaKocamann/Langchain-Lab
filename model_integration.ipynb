# %%
import os 
from dotenv import load_dotenv 
load_dotenv()

from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
response = model.invoke("Hi bro. How is it going?")
response
# Out:
# AIMessage(content="It's going well, thanks for asking. I'm just here to help with any questions or topics you'd like to discuss. How about you, how's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 43, 'total_tokens': 82, 'completion_time': 0.101517758, 'completion_tokens_details': None, 'prompt_time': 0.005426515, 'prompt_tokens_details': None, 'queue_time': 0.090429087, 'total_time': 0.106944273}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ccdfe-267f-7ef3-8152-6bf0dbe88c84-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 39, 'total_tokens': 82})

# %%
response.content
# Out:
# "It's going well, thanks for asking. I'm just here to help with any questions or topics you'd like to discuss. How about you, how's your day going so far?"

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end = "|", flush = True)
# Out:
# |Art|ificial| Intelligence| (|AI|)| has| revolution|ized| the| way| we| live| and| work|,| transforming| numerous| aspects| of| our| daily| lives|.| This| innovative| technology| enables| machines| to| think|,| learn|,| and| act| like| humans|,| making| it| an| integral| part| of| various| industries| such| as| healthcare|,| finance|,| and| transportation|.| AI|-powered| systems| can| analyze| vast| amounts| of| data|,| identify| patterns|,| and| make| informed| decisions|,| leading| to| increased| efficiency| and| productivity|.| From| virtual| assistants| like| Siri| and| Alexa| to| self|-driving| cars| and| personalized| recommendation| systems|,| AI| has| made| significant| strides| in| recent| years|.| Moreover|,| AI| has| the| potential| to| solve| complex| problems|,| such| as| disease| diagnosis| and| climate| change|,| by| providing| insights| and| predicting| outcomes|.| As| AI| continues| to| evolve|,| it| is| expected| to| have| a| profound| impact| on| the| job| market|,| education|,| and| social| interactions|,| necess|itating| a| need| for| humans| to| develop| new| skills| and| adapt| to| an| AI|-driven| world|.| Overall|,| AI| has| the| potential| to| revolution|ize| the| way| we| live|,| work|,| and| interact|,| and| its| applications| are| endless|,| making| it| an| exciting| and| rapidly| growing| field| of| research| and| development|.| With| its| vast| potential|,| AI| is| poised| to| shape| the| future| of| humanity|.|||

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "What is the capital of France?",
    "What is the meaning of life?"
])

for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, including:\n\n1. **Mating and Courtship**: Bright colors can be an attractive feature for potential mates. Parrots use their vibrant feathers to showcase their health, strength, and suitability as a partner. The more colorful the feathers, the more likely they are to attract a mate.\n2. **Communication and Social Signaling**: Colorful feathers can convey information about a parrot's identity, sex, age, and social status. Different colors can signal dominance, submission, or friendliness, helping parrots navigate their social hierarchy.\n3. **Camouflage and Warning**: Some parrots have evolved to blend in with their surroundings, using colors that match their environment to avoid predators. Others have bright, warning colors that signal to potential predators that they are toxic or distasteful.\n4. **Thermoregulation**: Some research suggests that the bright colors of parrots may help regulate their body temperature. The dark colors can absorb heat, while the light colors can reflect it, helping the parrot maintain a stable body temperature.\n5. **Evolutionary Adaptation**: Parrots have evolved in a variety of environments, and their colorful feathers may have developed as an adaptation to their specific ecosystem. For example, the bright colors of Amazon parrots may have evolved to match the vibrant colors of the rainforest flowers and fruits they eat.\n6. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as courtship displays, threat displays, or alarm calls. These displays can be used to deter predators, attract mates, or signal to other parrots.\n7. **Genetic Variation**: Genetic variation within parrot populations can lead to the development of new, colorful feather traits. These traits can then be passed on to future generations, contributing to the diversity of colors seen in parrots today.\n\nOverall, the colorful feathers of parrots serve multiple purposes, including communication, mating, camouflage, and thermoregulation. These vibrant colors are an essential part of a parrot's identity and play a crucial role in their social behavior and survival." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 427, 'prompt_tokens': 43, 'total_tokens': 470, 'completion_time': 1.2393244509999999, 'completion_tokens_details': None, 'prompt_time': 0.002030205, 'prompt_tokens_details': None, 'queue_time': 0.048164016, 'total_time': 1.241354656}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019cce06-3025-7b41-b6f0-6c26265bd579-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 427, 'total_tokens': 470}
# content='The capital of France is Paris.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.013669241, 'completion_tokens_details': None, 'prompt_time': 0.002497379, 'prompt_tokens_details': None, 'queue_time': 0.047069925, 'total_time': 0.01616662}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019cce06-3028-7c72-a2c2-1b8ac71d75b3-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}
# content='The question of the meaning of life is a profound and complex one that has been debated by philosophers, theologians, scientists, and many others for centuries. There is no one definitive answer, as the meaning of life can vary greatly depending on an individual\'s beliefs, values, and experiences.\n\nSome possible perspectives on the meaning of life include:\n\n1. **Hedonism**: The pursuit of pleasure and happiness is the primary goal of life.\n2. **Eudaimonia**: The cultivation of a state of being that is characterized by flourishing, fulfillment, and a sense of purpose.\n3. **Self-actualization**: The realization of one\'s full potential and the pursuit of personal growth and development.\n4. **Altruism**: The dedication to serving others and making a positive impact on the world.\n5. **Spiritual or religious**: The meaning of life is found in a higher power or a spiritual realm, and the purpose of life is to fulfill a divine plan or to achieve spiritual enlightenment.\n6. **Existentialism**: Life has no inherent meaning, and individuals must create their own purpose and meaning through their choices and actions.\n7. **Humanism**: The meaning of life is found in human relationships, experiences, and achievements, and the pursuit of knowledge, art, and culture.\n8. **Evolutionary**: The meaning of life is to survive and reproduce, and to contribute to the continuation of the species.\n9. **Personal growth**: The meaning of life is to learn, grow, and develop as an individual, and to become the best version of oneself.\n10. **Cosmological**: The meaning of life is connected to the universe and the laws of physics, and the purpose of life is to understand and appreciate the beauty and complexity of the cosmos.\n\nUltimately, the meaning of life is a deeply personal and subjective question that each individual must answer for themselves. It may involve a combination of these perspectives, or something entirely unique and individual.\n\nSome famous philosophers and thinkers have offered their own insights on the meaning of life, including:\n\n* **Aristotle**: "Happiness is the whole aim and end of human endeavors."\n* **Epicurus**: "Not what we have, but what we enjoy, constitutes our happiness."\n* **Jean-Paul Sartre**: "Man is condemned to be free; because once thrown into the world, he is forced to choose."\n* **Albert Camus**: "The only way to deal with an unfree world is to become so absolutely free that your very existence is an act of rebellion."\n* **Buddha**: "The purpose of life is to find happiness, and the key to happiness is to live in the present moment."\n\nThese perspectives and quotes offer a glimpse into the diverse and complex nature of the question, and highlight the importance of individual reflection and exploration in finding one\'s own meaning and purpose in life.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 586, 'prompt_tokens': 42, 'total_tokens': 628, 'completion_time': 1.380297334, 'completion_tokens_details': None, 'prompt_time': 0.00246013, 'prompt_tokens_details': None, 'queue_time': 0.048013948, 'total_time': 1.382757464}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019cce06-3029-7df1-a4a0-70932b600ee0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 586, 'total_tokens': 628}

# %%
model.batch([
    "Why do parrots have colorful feathers?",
    "What is the capital of France?",
    "What is the meaning of life?"],
    config = {
        "max_concurrency": 5
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers for several reasons:\n\n1. **Mating and Courtship**: Bright, vibrant feathers play a crucial role in attracting a mate. Parrots use their colorful plumage to showcase their health, strength, and genetic quality to potential partners. The more vibrant and intense the colors, the more attractive the parrot appears to be.\n2. **Communication and Social Status**: Colorful feathers help parrots communicate with each other and establish social hierarchies. Different colors can signal dominance, submission, or friendliness, allowing parrots to navigate their social groups effectively.\n3. **Camouflage and Protection**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural environments. For example, the blue and yellow feathers of some parrot species can blend in with the bright colors of tropical flowers or foliage, making it harder for predators to spot them.\n4. **Thermoregulation**: In some cases, the color of a parrot's feathers can help regulate its body temperature. Darker colors can absorb heat, while lighter colors can reflect it, helping the parrot to maintain a stable body temperature in varying environmental conditions.\n5. **Evolutionary Adaptation**: The evolutionary history of parrots has led to the development of colorful feathers as a way to adapt to their environments. Over time, parrots that had more vibrant colors may have had a selective advantage, such as being more attractive to mates or being better able to communicate with other parrots.\n6. **Visual Display**: Parrots also use their colorful feathers to create visual displays, such as fanning their tails or raising their crests, to signal aggression, courtship, or alarm. These displays can be an important part of parrot behavior and social interaction.\n\nIn summary, the colorful feathers of parrots serve multiple purposes, including attracting mates, communicating with other parrots, camouflage, thermoregulation, evolutionary adaptation, and visual display.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 401, 'prompt_tokens': 43, 'total_tokens': 444, 'completion_time': 1.5481030470000001, 'completion_tokens_details': None, 'prompt_time': 0.00399576, 'prompt_tokens_details': None, 'queue_time': 0.053048781, 'total_time': 1.5520988070000001}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cce07-f1f7-7ac1-b64a-bb8e16171bae-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 401, 'total_tokens': 444}),
#  AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.009273375, 'completion_tokens_details': None, 'prompt_time': 0.007720175, 'prompt_tokens_details': None, 'queue_time': 0.062598532, 'total_time': 0.01699355}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cce07-f1f9-7511-bb01-db50287cb602-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}),
#  AIMessage(content="The question of the meaning of life is a complex and subjective one that has been debated by philosophers, theologians, scientists, and many others for centuries. There is no one definitive answer, as the meaning of life can vary greatly from person to person and culture to culture. However, here are some possible perspectives:\n\n1. **Biological perspective**: From a biological standpoint, the meaning of life could be to survive and reproduce, as these are the fundamental drives that have enabled life to thrive on Earth.\n2. **Religious or spiritual perspective**: Many people find meaning in life through their faith or spiritual beliefs, which often provide a sense of purpose, morality, and connection to something greater than themselves.\n3. **Philosophical perspective**: Philosophers have proposed various theories about the meaning of life, such as:\n\t* **Hedonism**: The pursuit of happiness and pleasure.\n\t* **Eudaimonism**: The cultivation of virtues and living a fulfilling life.\n\t* **Existentialism**: The creation of one's own meaning and purpose in life.\n\t* **Absurdism**: The acceptance of the absurdity and uncertainty of life, and finding ways to create meaning despite it.\n4. **Personal perspective**: Each individual may find their own unique meaning in life, based on their values, passions, and experiences. This could involve:\n\t* **Pursuing one's passions**: Engaging in activities that bring joy and fulfillment.\n\t* **Building relationships**: Nurturing connections with family, friends, and community.\n\t* **Making a positive impact**: Contributing to the greater good, whether through work, volunteering, or other activities.\n\t* **Personal growth**: Continuously learning, self-reflecting, and improving oneself.\n5. **Psychological perspective**: Research in psychology has identified factors that contribute to a sense of meaning and fulfillment in life, such as:\n\t* **Flow experiences**: Engaging in activities that challenge and absorb us.\n\t* **Positive relationships**: Having supportive and meaningful relationships.\n\t* **Purpose and direction**: Having a sense of direction and goals in life.\n\t* **Self-awareness**: Understanding one's own strengths, weaknesses, and values.\n\nUltimately, the meaning of life is a deeply personal and subjective question that each individual must answer for themselves. It may evolve over time as we grow, learn, and experience new things. What gives your life meaning?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 492, 'prompt_tokens': 42, 'total_tokens': 534, 'completion_time': 1.260798228, 'completion_tokens_details': None, 'prompt_time': 0.006044735, 'prompt_tokens_details': None, 'queue_time': 0.056780779, 'total_time': 1.266842963}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ce7bc1685b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cce07-f1fb-78a1-9738-a6d3b3232ccf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 492, 'total_tokens': 534})]
